# %%
import mlflow

# Check where MLflow is currently saving
print(mlflow.get_tracking_uri())

# Manually set and verify
mlflow.set_tracking_uri(r"C:\Project 2 - XGBoost\credit-risk-prediction\mlruns")
print(mlflow.get_tracking_uri())

# Check if experiment exists
exp = mlflow.get_experiment_by_name("home-credit-default-risk")
print(f"Experiment: {exp}")
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\pydantic\_internal\_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# file:///C:/Project%202%20-%20XGBoost/credit-risk-prediction/mlruns
# C:\Project 2 - XGBoost\credit-risk-prediction\mlruns
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mlflow\tracking\registry.py:81, in StoreRegistry.get_store_builder(self, store_uri)
#      80 try:
# ---> 81     store_builder = self._registry[scheme]
#      82 except KeyError:
#
# KeyError: 'c'
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedModelRegistryStoreURIException Traceback (most recent call last)
# Cell In[1], line 11
# ...

# %%
import mlflow
import os

# ✅ Convert Windows path to proper file URI for MLflow
tracking_path = r"C:\Project 2 - XGBoost\credit-risk-prediction\mlruns"
tracking_uri   = "file:///" + tracking_path.replace("\\", "/")
print(f"Tracking URI: {tracking_uri}")

mlflow.set_tracking_uri(tracking_uri)
mlflow.set_experiment("home-credit-default-risk")

exp = mlflow.get_experiment_by_name("home-credit-default-risk")
print(f"Experiment: {exp}")
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)
# 2026/03/22 19:53:04 INFO mlflow.tracking.fluent: Experiment with name 'home-credit-default-risk' does not exist. Creating a new experiment.
# Tracking URI: file:///C:/Project 2 - XGBoost/credit-risk-prediction/mlruns
# Experiment: <Experiment: artifact_location=('file:///C:/Project 2 - '
#  'XGBoost/credit-risk-prediction/mlruns/815233954846200051'), creation_time=1774189384953, experiment_id='815233954846200051', last_update_time=1774189384953, lifecycle_stage='active', name='home-credit-default-risk', tags={}, workspace='default'>

# %%
import sys
sys.path.append(r'C:\Project 2 - XGBoost\credit-risk-prediction')
from src.train import run_training_pipeline_with_mlflow
print("✅ Import successful")
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\pydantic\_internal\_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# ✅ Import successful

# %%
import sys
import os
sys.path.append(r'C:\Project 2 - XGBoost\credit-risk-prediction')
os.chdir(r'C:\Project 2 - XGBoost\credit-risk-prediction')

import src.config as cfg
cfg.N_TRIALS = 5
cfg.CV_FOLDS = 2

from src.data_loader import load_train, build_dataset, clean
from src.feature_engineering import build_features, get_X_y
from src.train import run_training_pipeline_with_mlflow

# Reload data
df = load_train()
df = build_dataset(df)
df = clean(df)
df, encoders = build_features(df)
X, y = get_X_y(df)

# Now run MLflow pipeline
final_model, metrics, best_params = run_training_pipeline_with_mlflow(X, y)
# Out:
#   ✅ application_train.csv                           (307511, 122)
#
# Merging auxiliary tables...
#   ✅ bureau.csv                                      (1716428, 17)
#   ✅ bureau_balance.csv                              (27299925, 3)
#   After Bureau + Balance          shape: (307511, 139)
#   ✅ POS_CASH_balance.csv                            (10001358, 8)
#   After POS Cash                  shape: (307511, 144)
#   ✅ previous_application.csv                        (1670214, 37)
#   After Previous Application      shape: (307511, 154)
#   ✅ installments_payments.csv                       (13605401, 8)
#   After Installments              shape: (307511, 166)
#   ✅ credit_card_balance.csv                         (3840312, 23)
#   After Credit Card               shape: (307511, 176)
#
# Building features...
#   After application features : (307511, 154)
#   After EXT_SOURCE features  : (307511, 159)
#   After label encoding       : (307511, 159)
# ...

# %%
# Run this once after get_X_y — saves ~8 min every restart
import pandas as pd
df.to_parquet(r'C:\Project 2 - XGBoost\credit-risk-prediction\data\processed_train.parquet')
print("Saved!")
# Out:
# Saved!
